# %% [markdown]
# # Content List

# %% [markdown]
# 01 Importing Libraries
# 02 Importing Dataframes
# 03 If Statement
# 04 If-Statements with the loc() Function
# 05 If-Statements with For-Loops
# 06 Exercise

# %% [markdown]
# # 01 Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing Dataframe

# %%
path = r'/Users/a/Career Foundry/Achievement 4/02 Data/02 Prepared Data'

# %%
path
# Out:
# '/Users/a/Career Foundry/Achievement 4/02 Data/02 Prepared Data'

# %%
df_ords = pd.read_csv(os.path.join(path, 'orders_products_merged.csv'), index_col = False)

# %%
df = df_ords[:1000000]

# %% [markdown]
# # 03 If Statement

# %%
# Define a function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Applying the function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/f_/g56842ln7h53rh_q348szshw0000gp/T/ipykernel_2454/3520053958.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    631049
# Low-range product    368951
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.0

# %% [markdown]
# # 04 If-Statements with the loc() Function

# %%
df_ords.loc[df_ords['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords.loc[(df_ords['prices'] <= 15) & (df_ords['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords.loc[df_ords['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    1238106
# Low-range product     391208
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # 05 If-Statements with For-Loops

# %%
df_ords['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    290175
# 1.0    288103
# 2.0    202195
# 5.0    199345
# 6.0    195365
# 3.0    180988
# 4.0    178024
# NaN     95119
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in df_ords["orders_day_of_week"]:
  if value == 0:
    result.append("busiest day")
  elif value == 4:
    result.append("least busy")
  else:
    result.append("regularly busy")

# %%
result
# Out:
# ['regularly busy',
#  'regularly busy',
#  'least busy',
#  'least busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'least busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'least busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'least busy',
#  'least busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'least busy',
# ...

# %%
df_ords["busiest_day"] = result

# %%
df_ords["busiest_day"].value_counts(dropna = False)
# Out:
# regularly busy    1161115
# busiest day        290175
# least busy         178024
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 06 Exercise

# %% [markdown]
# # Creating a new column for busiest_days

# %%
result = []

for value in df_ords["orders_day_of_week"]:
  if value == 0 & 1:
    result.append("Busiest days")
  elif value == 3 & 4:
    result.append("Slowest days")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Creating a new column busiest_days

df_ords["busiest_days"] = result

# %%
# Printing frequency of busiest_days

df_ords["busiest_days"].value_counts(dropna = False)
# Out:
# Regularly busy    1339139
# Busiest days       290175
# Name: busiest_days, dtype: int64

# %%
df_ords.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1  order_id  user_id  order_number  \
# 0           0           1.0           1.0   2398795      1.0           2.0
# 1           1           2.0           2.0    473747      1.0           3.0
# 2           2           3.0           3.0   2254736      1.0           4.0
# 3           3           4.0           4.0    431534      1.0           5.0
# 4           4           5.0           5.0   3367565      1.0           6.0
#
#    orders_day_of_week  time_orders  days_since_prior_order  product_id  ...  \
# 0                 3.0          7.0                    15.0       196.0  ...
# 1                 3.0         12.0                    21.0       196.0  ...
# 2                 4.0          7.0                    29.0       196.0  ...
# 3                 4.0         15.0                    28.0       196.0  ...
# 4                 2.0          7.0                    19.0       196.0  ...
#
# ...

# %% [markdown]
# # Creating a new column for busiest_period_of_day

# %%
# Frequency of time_orders to find out the which hour is the busiest

df_ords['time_orders'].value_counts(dropna = False)
# Out:
# 10.0    137149
# 11.0    129378
# 9.0     128436
# 14.0    124930
# 15.0    123568
# 13.0    122582
# 12.0    119703
# 16.0    117281
# NaN      95119
# 17.0     94479
# 8.0      90031
# 18.0     73577
# 19.0     56704
# 7.0      46807
# 20.0     44818
# 21.0     37420
# 22.0     29315
# 23.0     18149
# 6.0      14539
# 0.0       9459
# 1.0       4815
# 5.0       4127
# 2.0       2774
# 4.0       2205
# 3.0       1949
# Name: time_orders, dtype: int64

# %% [markdown]
# The busiest hour for orders is 10 am

# %%
result = []

for value in df_ords["time_orders"]:
  if value == 10:
    result.append("Most orders")
  elif value == 19:
    result.append("Average orders")
  else:
    result.append("Fewest orders")

# %%
result
# Out:
# ['Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
# ...

# %%
# Creating a new column 

df_ords["busiest_period_of_day"] = result

# %%
# Printing frequency of busiest_period_of_day

df_ords["busiest_period_of_day"].value_counts(dropna = False)
# Out:
# Fewest orders     1435461
# Most orders        137149
# Average orders      56704
# Name: busiest_period_of_day, dtype: int64

# %%
# Exporting altered dataframe

path = r'/Users/a/Career Foundry/Achievement 4/02 Data/02 Prepared Data'

# %%
path
# Out:
# '/Users/a/Career Foundry/Achievement 4/02 Data/02 Prepared Data'

# %%
df_ords.to_pickle(os.path.join(path,'orders_products_altered.pkl'))
